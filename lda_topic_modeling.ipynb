# %% [markdown]
# Sample LDA model in pyspark. Clusters data into topics and maps the words associated with each topic.

# %%
dbutils.library.installPyPI('nltk', '3.4.3')
dbutils.library.installPyPI('xlrd')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PyPI package nltk has been installed already. The previously-installed package is `nltk==3.4.3`. To resolve this issue detach and re-attach the notebook to create a new environment or rename the package.
# Out[5]: True</div>

# %%
import nltk
import re
from operator import attrgetter
from string import punctuation
from pyspark.ml import Pipeline
from pyspark.ml.feature import CountVectorizer, IDF
from pyspark.sql.types import StringType, ArrayType, FloatType, IntegerType
from pyspark.sql.functions import array, concat, concat_ws, split, lit, col, array_max, array_position
from pyspark.ml.clustering import LDA

nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
ps = nltk.PorterStemmer()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# </div>

# %%
# Text Parser {

def strip_digits(strval):
    return re.sub(r'\d+','',strval) 

def strip_punctuation(strval):
    punc_free = ''.join(' ' if char in punctuation else char
                        for char in strval)
    return punc_free
  
def tokenize_text(text):
    '''Tokenizes strings, removes stopwords and stems.'''
    
    digit_free = strip_digits(text)
    punc_free = strip_punctuation(digit_free)
    tokens = re.split('\W+', punc_free)
    result = list(
        filter(
            None, 
            [ps.stem(word).lower() for word in tokens if word not in stopwords]
        )
    )
    return result

# } Topic Extractor {

def indices_to_terms(vocabulary):
    def indices_to_terms(index, count):
        return [vocabulary[int(x)] for x in index][:count]
    return udf(indices_to_terms, ArrayType(StringType()))

# Create udf functions
StringArrayType = ArrayType(StringType(), False)
tokenize_udf = udf(tokenize_text, StringArrayType)
to_array = udf(lambda v: v.toArray().tolist(), ArrayType(FloatType()))
array_index = udf(lambda x,y: [i for i, e in enumerate(x) if e==y ][0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = pd.read_excel('http://help.incites.clarivate.com/incitesLiveESI/10678-TRS/version/default/part/AttachmentData/data/ESIMasterJournalList-122018.xlsx')

df = spark.createDataFrame(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Tokenize Text
df_token = df.select('Full title').withColumn("text_data", tokenize_udf('Full title'))

# Make tf-idf vectorizer
cv = CountVectorizer(
    inputCol="text_data",
    outputCol="count_vec", minDF=1
)
# transform the data
cvModel = cv.fit(df_token)
featurizedData = cvModel.transform(df_token)
idf = IDF(inputCol="count_vec", outputCol="features")

idfModel = idf.fit(featurizedData)
df_feature = idfModel.transform(featurizedData)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(df_feature)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Run the LDA model
lda = LDA(k=20, seed=1)
model = lda.fit(df_feature)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(model.describeTopics(maxTermsPerTopic = 15))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Map the term indices to the topic vocabulary (numbers to words).
df_terms = model.describeTopics(maxTermsPerTopic = 15).withColumn(
    "topic_words", indices_to_terms(cvModel.vocabulary)("termIndices", lit(5)))

# %%
# display(df_terms)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Map the topic number to the highest probability 
df_model = model.transform(df_feature).withColumn('test', to_array('topicDistribution')).withColumn('topic', array_index('test', array_max('test')))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(df_model)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_model.join(df_terms, ['topic']).select('topic', 'Full title', 'topic_words'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>topic</th><th>Full title</th><th>topic_words</th></tr></thead><tbody><tr><td>19</td><td>2D Materials</td><td>List(appli, econom, journal, inform, of)</td></tr><tr><td>11</td><td>3 Biotech</td><td>List(environ, work, associ, disord, ac)</td></tr><tr><td>19</td><td>3D Printing and Additive Manufacturing</td><td>List(appli, econom, journal, inform, of)</td></tr><tr><td>1</td><td>4OR-A Quarterly Journal of Operations Research</td><td>List(acta, pharmaceut, design, famili, e)</td></tr><tr><td>5</td><td>AAPG BULLETIN</td><td>List(scienc, review, nurs, plant, of)</td></tr><tr><td>10</td><td>AAPS Journal</td><td>List(method, pharmacolog, conserv, china, univers)</td></tr><tr><td>10</td><td>AAPS PHARMSCITECH</td><td>List(method, pharmacolog, conserv, china, univers)</td></tr><tr><td>15</td><td>AATCC Journal of Research</td><td>List(intern, studi, law, languag, polit)</td></tr><tr><td>15</td><td>AATCC REVIEW</td><td>List(intern, studi, law, languag, polit)</td></tr><tr><td>7</td><td>Abacus-A Journal of Accounting Finance and Business Studies</td><td>List(de, revista, water, busi, therapeut)</td></tr><tr><td>6</td><td>Abdominal Radiology</td><td>List(mathemat, oncolog, network, radiolog, intervent)</td></tr><tr><td>4</td><td>ABHANDLUNGEN AUS DEM MATHEMATISCHEN SEMINAR DER UNIVERSITAT HAMBURG</td><td>List(annal, advanc, archiv, health, seminar)</td></tr><tr><td>18</td><td>ABSTRACTS OF PAPERS OF THE AMERICAN CHEMICAL SOCIETY</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>7</td><td>Academia-Revista Latinoamericana de Administracion</td><td>List(de, revista, water, busi, therapeut)</td></tr><tr><td>19</td><td>ACADEMIC EMERGENCY MEDICINE</td><td>List(appli, econom, journal, inform, of)</td></tr><tr><td>19</td><td>ACADEMIC MEDICINE</td><td>List(appli, econom, journal, inform, of)</td></tr><tr><td>19</td><td>Academic Pediatrics</td><td>List(appli, econom, journal, inform, of)</td></tr><tr><td>19</td><td>ACADEMIC PSYCHIATRY</td><td>List(appli, econom, journal, inform, of)</td></tr><tr><td>19</td><td>ACADEMIC RADIOLOGY</td><td>List(appli, econom, journal, inform, of)</td></tr><tr><td>18</td><td>Academy of Management Annals</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>ACADEMY OF MANAGEMENT JOURNAL</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>Academy of Management Learning & Education</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>Academy of Management Perspectives</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>ACADEMY OF MANAGEMENT REVIEW</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>11</td><td>ACAROLOGIA</td><td>List(environ, work, associ, disord, ac)</td></tr><tr><td>4</td><td>ACCIDENT ANALYSIS AND PREVENTION</td><td>List(annal, advanc, archiv, health, seminar)</td></tr><tr><td>4</td><td>Accountability in Research-Policies and Quality Assurance</td><td>List(annal, advanc, archiv, health, seminar)</td></tr><tr><td>18</td><td>ACCOUNTING AND BUSINESS RESEARCH</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>Accounting and Finance</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>Accounting Auditing & Accountability Journal</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>4</td><td>Accounting Forum</td><td>List(annal, advanc, archiv, health, seminar)</td></tr><tr><td>11</td><td>Accounting Horizons</td><td>List(environ, work, associ, disord, ac)</td></tr><tr><td>18</td><td>ACCOUNTING ORGANIZATIONS AND SOCIETY</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>ACCOUNTING REVIEW</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>18</td><td>ACCOUNTS OF CHEMICAL RESEARCH</td><td>List(the, of, engin, societi, manag)</td></tr><tr><td>4</td><td>ACCREDITATION AND QUALITY ASSURANCE</td><td>List(annal, advanc, archi ...
